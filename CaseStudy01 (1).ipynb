# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Read the dataset to the python environment.

# %%
data=pd.read_csv('cars_data.csv')

# %%
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %% [markdown]
# # 2. Check for the null values present in the dataset.

# %%
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # 3.Plot a bar graph of male vs female buyers participated in the sales

# %%
bg=df["Buyer Gender"].value_counts()
bg.plot(kind='bar')
plt.title('Male v/s Female buyers',fontsize=16,)
plt.show()

# %%
#No:of male and female buyers
data['Buyer Gender'].value_counts()
# Out:
# Female    5052
# Male      4948
# Name: Buyer Gender, dtype: int64

# %% [markdown]
# # 4.Find the top 5 cars based on their sales price.

# %%
top=pd.DataFrame(data,columns=['Make','Model','Nickname','Sale Price'])

# %%
top
# Out:
#          Make        Model    Nickname  Sale Price
# 0      Suzuki       Vitara  Philippine    54806.14
# 1       Honda        S2000      Henrik    51826.30
# 2         BMW           Z4      Lebbie    82929.14
# 3      Toyota       Tacoma    Jefferey    56928.66
# 4        Ford      Festiva     Glendon    77201.26
# ...       ...          ...         ...         ...
# 9995    Mazda      Tribute      Cooper    58580.65
# 9996      GMC  Sierra 2500         Dud    75229.74
# 9997  Mercury      Mariner     Chariot    34755.44
# 9998   Daewoo      Leganza       Dynah    98725.42
# 9999   Toyota      Sequoia    Zedekiah    96769.78
#
# [10000 rows x 4 columns]

# %%
top.nlargest(5,['Sale Price'])
# Out:
#             Make      Model   Nickname  Sale Price
# 5984  Volkswagen  Jetta III    Rachael    99997.65
# 1270        Audi         A6      Thorn    99991.91
# 3460       Lexus         LX      Aldin    99983.38
# 9032       Mazda       MX-6  Sylvester    99978.17
# 302        Lexus         ES       Brig    99973.44

# %%
#Entire details of the top 5 cars based on their sale price
data.nlargest(5,['Sale Price'])
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  \
# 5984               core    Russia    Krasnoyarka        59.418208
# 1270           function    Latvia        Līgatne        57.236340
# 3460           software  Malaysia      Pasir Mas         6.109065
# 9032  internet solution    Russia  Krutaya Gorka        55.369917
# 302         user-facing    Canada       Langford        48.447463
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %% [markdown]
# # 5.Find the least 5 cars based on their Resell price

# %%
least=pd.DataFrame(data,columns=['Make','Model','Nickname','Resell Price'])

# %%
least
# Out:
#          Make        Model    Nickname  Resell Price
# 0      Suzuki       Vitara  Philippine      33858.32
# 1       Honda        S2000      Henrik       2989.28
# 2         BMW           Z4      Lebbie      35049.16
# 3      Toyota       Tacoma    Jefferey       8236.15
# 4        Ford      Festiva     Glendon      32765.76
# ...       ...          ...         ...           ...
# 9995    Mazda      Tribute      Cooper      42640.82
# 9996      GMC  Sierra 2500         Dud      21115.58
# 9997  Mercury      Mariner     Chariot       2731.25
# 9998   Daewoo      Leganza       Dynah      18718.58
# 9999   Toyota      Sequoia    Zedekiah       4545.95
#
# [10000 rows x 4 columns]

# %%
least.nsmallest(5,'Resell Price')
# Out:
#             Make        Model Nickname  Resell Price
# 2446   Chevrolet         1500  Corenda       2000.84
# 4933         GMC  Savana 1500     Lark       2005.44
# 566       Jaguar           XF   Payton       2014.09
# 2538  Mitsubishi       3000GT     Thia       2017.24
# 5869    Infiniti          G37    Sonny       2017.83

# %%
#Entire details of the least 5 cars based on their resell price
data.nsmallest(5,'Resell Price')
# Out:
#             Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 2446   Chevrolet         1500  Corenda       Male       Female         25
# 4933         GMC  Savana 1500     Lark     Female       Female         34
# 566       Jaguar           XF   Payton     Female         Male         64
# 2538  Mitsubishi       3000GT     Thia     Female       Female         25
# 5869    Infiniti          G37    Sonny       Male         Male         20
#
#             Buzzword      Country              City  Dealer Latitude  \
# 2446   collaboration  Philippines           Tubigan         8.490877
# 4933     interactive       Poland       Śródmieście        53.838651
# 566        Visionary      Nigeria       Ikot-Ekpene         5.174447
# 2538  well-modulated        China        Yanweigang        34.509325
# 5869      optimizing       France  Clermont-Ferrand        45.786764
#
#       Dealer Longitude      Color  New Car Purchase Date  Sale Price  \
# ...
